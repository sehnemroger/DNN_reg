# %% [markdown]
# # Importing necessary packages

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# # Generating data

# %% [markdown]
# ## Function to be fitted

# %%
def function(x):
  y = x*np.sin(.5*x*np.sin(.5*x*np.cos(x)))
  return y
vf = np.vectorize(function)

# %% [markdown]
# ### Plot the function

# %%
init = -3*np.pi
endval = 3*np.pi
step = .0001
x = np.arange(init,endval+step,step)
y = vf(x) + .1*np.random.rand(np.size(x))
plt.plot(x,y)

# %% [markdown]
# ## Randomizing and divinding data into test and train sets

# %%
p = np.random.permutation(len(x)) # Create a random permutation 
x_perm = x[p]
y_perm = y[p] # Aplling same permutation on both

# %% [markdown]
# ### Plotting to see if nothing changed (sceptical people go :D )

# %%
#plt.plot(x,y)
#plt.plot(x_perm,y_perm,',r')

# %% [markdown]
# ### Train set and test set, train set is 80% of the data

# %%
x_train_full , x_test , y_train_full, y_test = x_perm[:int(np.floor(.8*len(x)))], x_perm[int(np.floor(.8*len(x))):], y_perm[:int(np.floor(.8*len(x)))], y_perm[int(np.floor(.8*len(x))):]

# %% [markdown]
# #### Since all the training data is mixed the plot is the same (except for the blank spots)

# %%
#plt.plot(x_train_full,y_train_full,',r')

# %%
#plt.plot(x_test,y_test,',b')

# %% [markdown]
# ### Validation and training set

# %%
x_train, x_valid, y_train, y_valid = x_train_full[:int(np.floor(.8*len(x)))], x_train_full[int(np.floor(.8*len(x))):], y_train_full[:int(np.floor(.8*len(x)))], y_train_full[int(np.floor(.8*len(x))):]

# %% [markdown]
# # Making the DNN

# %% [markdown]
# #### Using keras functional api to construct the the  problem
# #### Unsing wide and deep neural net

# %%
input_ = keras.layers.Input(shape=(1,))
hidden_y = keras.layers.Dense(10, activation="tanh")(input_)
nn_layers = 5
for e_layer in range (nn_layers):
    hidden_x = keras.layers.Dense(5, activation="tanh")(hidden_y)
    n_layers = 3
    for layer in range(n_layers):
        hidden_x = keras.layers.Dense(5, activation="elu")(hidden_x)
        #hidden_x = keras.layers.Dropout(rate=0.1)(hidden_x)
    concat = keras.layers.Concatenate()([input_,hidden_y,hidden_x])
    hidden_y = keras.layers.Dense(6, activation="tanh")(concat)
hidden_out_2 = keras.layers.Dense(5, activation="tanh")(hidden_y)
output = keras.layers.Dense(1)(hidden_out_2)
model = keras.Model(inputs=[input_], outputs=[output])

# %% [markdown]
# ## Compiling the DNN

# %%
model.compile(loss="mse", optimizer=keras.optimizers.Nadam(lr=0.001))

# %% [markdown]
# ## Seeing the DNN

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           20          input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 5)            55          dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 5)            30          dense_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 5)            30          dense_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 5)            30          dense_3[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 16)           0           input_1[0][0]
#                                                                  dense[0][0]
#                                                                  dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 6)            102         concatenate[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 5)            35          dense_5[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 5)            30          dense_6[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 5)            30          dense_7[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 5)            30          dense_8[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 12)           0           input_1[0][0]
#                                                                  dense_5[0][0]
#                                                                  dense_9[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 6)            78          concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 5)            35          dense_10[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 5)            30          dense_11[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 5)            30          dense_12[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 5)            30          dense_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 12)           0           input_1[0][0]
#                                                                  dense_10[0][0]
#                                                                  dense_14[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 6)            78          concatenate_2[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 5)            35          dense_15[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 5)            30          dense_16[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 5)            30          dense_17[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 5)            30          dense_18[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 12)           0           input_1[0][0]
#                                                                  dense_15[0][0]
#                                                                  dense_19[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 6)            78          concatenate_3[0][0]
# __________________________________________________________________________________________________
# dense_21 (Dense)                (None, 5)            35          dense_20[0][0]
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 5)            30          dense_21[0][0]
# __________________________________________________________________________________________________
# dense_23 (Dense)                (None, 5)            30          dense_22[0][0]
# __________________________________________________________________________________________________
# dense_24 (Dense)                (None, 5)            30          dense_23[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 12)           0           input_1[0][0]
#                                                                  dense_20[0][0]
#                                                                  dense_24[0][0]
# __________________________________________________________________________________________________
# dense_25 (Dense)                (None, 6)            78          concatenate_4[0][0]
# __________________________________________________________________________________________________
# dense_26 (Dense)                (None, 5)            35          dense_25[0][0]
# __________________________________________________________________________________________________
# dense_27 (Dense)                (None, 1)            6           dense_26[0][0]
# ==================================================================================================
# Total params: 1,120
# Trainable params: 1,120
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
keras.utils.plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# ## Fitting the DNN

# %%
device_name = tf.test.gpu_device_name()
if device_name == '/device:GPU:0':
  print('Found GPU at: {}'.format(device_name))
  with tf.device(device_name):
    history = model.fit(x_train,y_train, epochs=30, validation_data=(x_valid,y_valid))
else:
  history = model.fit(x_train,y_train, epochs=30, validation_data=(x_valid,y_valid))
# Out:
# Epoch 1/30
# 4713/4713 [==============================] - 12s 2ms/step - loss: 9.5926
# Epoch 2/30
# 4713/4713 [==============================] - 7s 2ms/step - loss: 7.2155
# Epoch 3/30
# 4713/4713 [==============================] - 8s 2ms/step - loss: 7.4140
# Epoch 4/30
# 4713/4713 [==============================] - 9s 2ms/step - loss: 5.9821
# Epoch 5/30
# 4713/4713 [==============================] - 9s 2ms/step - loss: 5.1269
# Epoch 6/30
# 4713/4713 [==============================] - 8s 2ms/step - loss: 6.0717
# Epoch 7/30
# 4713/4713 [==============================] - 8s 2ms/step - loss: 5.9119
# Epoch 8/30
# 4713/4713 [==============================] - 8s 2ms/step - loss: 4.1312
# Epoch 9/30
# 4713/4713 [==============================] - 9s 2ms/step - loss: 5.9721
# Epoch 10/30
# 4713/4713 [==============================] - 8s 2ms/step - loss: 4.4059
# Epoch 11/30
# 4713/4713 [==============================] - 7s 2ms/step - loss: 3.6073
# Epoch 12/30
# 4713/4713 [==============================] - 7s 1ms/step - loss: 3.7013
# Epoch 13/30
# 4713/4713 [==============================] - 8s 2ms/step - loss: 2.5090
# Epoch 14/30
# 4713/4713 [==============================] - 7s 2ms/step - loss: 4.0126
# Epoch 15/30
# 4713/4713 [==============================] - 8s 2ms/step - loss: 3.7707
# Epoch 16/30
# 4713/4713 [==============================] - 9s 2ms/step - loss: 3.4709
# Epoch 17/30
# 4713/4713 [==============================] - 6s 1ms/step - loss: 2.2110
# Epoch 18/30
# 4713/4713 [==============================] - 7s 1ms/step - loss: 1.4300
# Epoch 19/30
# 4713/4713 [==============================] - 7s 1ms/step - loss: 2.5952
# Epoch 20/30
# 4713/4713 [==============================] - 7s 1ms/step - loss: 1.6171
# Epoch 21/30
# 4713/4713 [==============================] - 8s 2ms/step - loss: 1.3757
# Epoch 22/30
# 4713/4713 [==============================] - 9s 2ms/step - loss: 1.1244
# Epoch 23/30
# 4713/4713 [==============================] - 7s 1ms/step - loss: 0.9212
# Epoch 24/30
# 4713/4713 [==============================] - 7s 1ms/step - loss: 1.4225
# Epoch 25/30
# 4713/4713 [==============================] - 7s 1ms/step - loss: 0.6742
# Epoch 26/30
# 4713/4713 [==============================] - 8s 2ms/step - loss: 1.0584
# Epoch 27/30
# 4713/4713 [==============================] - 8s 2ms/step - loss: 0.5758
# Epoch 28/30
# 4713/4713 [==============================] - 8s 2ms/step - loss: 0.4637
# Epoch 29/30
# 4713/4713 [==============================] - 8s 2ms/step - loss: 0.4063
# Epoch 30/30
# 4713/4713 [==============================] - 8s 2ms/step - loss: 0.5725

# %%
mse_test = model.evaluate(x_test, y_test)
# Out:
# 1179/1179 [==============================] - 1s 628us/step - loss: 1.9327

# %%
x_new = np.arange(-4*np.pi,4*np.pi+step*100,step*100)
y_new = model.predict(x_new)
plt.plot(x_new,y_new,',b')
plt.plot(x,y,'r')
