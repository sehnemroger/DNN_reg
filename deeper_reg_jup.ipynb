# %% [markdown]
# # Importing necessary packages

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# # Generating data

# %% [markdown]
# ## Function to be fitted

# %%
def function(x):
  y = x*np.sin(.5*x*np.sin(.5*x*np.cos(x)))
  return y
vf = np.vectorize(function)

# %% [markdown]
# ### Plot the function

# %%
init = -3*np.pi
endval = 3*np.pi
step = .0005
x = np.arange(init,endval+step,step)
y = vf(x) + .1*np.random.rand(np.size(x))
plt.plot(x,y)

# %% [markdown]
# ## Randomizing and divinding data into test and train sets

# %%
p = np.random.permutation(len(x)) # Create a random permutation 
x_perm = x[p]
y_perm = y[p] # Aplling same permutation on both

# %% [markdown]
# ### Plotting to see if nothing changed (sceptical people go :D )

# %%
#plt.plot(x,y)
#plt.plot(x_perm,y_perm,',r')

# %% [markdown]
# ### Train set and test set, train set is 80% of the data

# %%
x_train_full , x_test , y_train_full, y_test = x_perm[:int(np.floor(.8*len(x)))], x_perm[int(np.floor(.8*len(x))):], y_perm[:int(np.floor(.8*len(x)))], y_perm[int(np.floor(.8*len(x))):]

# %% [markdown]
# #### Since all the training data is mixed the plot is the same (except for the blank spots)

# %%
#plt.plot(x_train_full,y_train_full,',r')

# %%
#plt.plot(x_test,y_test,',b')

# %% [markdown]
# ### Validation and training set

# %%
x_train, x_valid, y_train, y_valid = x_train_full[:int(np.floor(.8*len(x_train_full)))], x_train_full[int(np.floor(.8*len(x_train_full))):], y_train_full[:int(np.floor(.8*len(x_train_full)))], y_train_full[int(np.floor(.8*len(x_train_full))):]

# %%
plt.plot(x_train,y_train,',r')

# %% [markdown]
# # Making the DNN

# %% [markdown]
# #### Using keras functional api to construct the the  problem
# #### Unsing wide and deep neural net

# %%
input_ = keras.layers.Input(shape=(1,))
hidden_y = keras.layers.Dense(10, activation="tanh")(input_)
nn_layers = 5
for e_layer in range (nn_layers):
    hidden_x = keras.layers.Dense(10, activation="tanh")(hidden_y)
    n_layers = 2
    for layer in range(n_layers):
        hidden_x = keras.layers.Dense(5, activation="tanh")(hidden_x)
        #hidden_x = keras.layers.Dropout(rate=0.1)(hidden_x)
    concat = keras.layers.Concatenate()([input_,hidden_y,hidden_x])
    hidden_y = keras.layers.Dense(6, activation="tanh")(concat)
hidden_out_2 = keras.layers.Dense(5, activation="tanh")(hidden_y)
output = keras.layers.Dense(1)(hidden_out_2)
model = keras.Model(inputs=[input_], outputs=[output])

# %% [markdown]
# ## Compiling the DNN

# %%
lr_scheduler = keras.callbacks.ReduceLROnPlateau(factor=0.7, patience=5, verbose=1, min_lr=0.0001)
early_stop = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=20, restore_best_weights=True)
model.compile(loss="mse", optimizer=keras.optimizers.Nadam(lr=0.001))

# %% [markdown]
# ## Seeing the DNN

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           20          input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           110         dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 5)            55          dense_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 5)            30          dense_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 16)           0           input_1[0][0]
#                                                                  dense[0][0]
#                                                                  dense_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 6)            102         concatenate[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 10)           70          dense_4[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 5)            55          dense_5[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 5)            30          dense_6[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 12)           0           input_1[0][0]
#                                                                  dense_4[0][0]
#                                                                  dense_7[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 6)            78          concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 10)           70          dense_8[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 5)            55          dense_9[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 5)            30          dense_10[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 12)           0           input_1[0][0]
#                                                                  dense_8[0][0]
#                                                                  dense_11[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 6)            78          concatenate_2[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 10)           70          dense_12[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 5)            55          dense_13[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 5)            30          dense_14[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 12)           0           input_1[0][0]
#                                                                  dense_12[0][0]
#                                                                  dense_15[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 6)            78          concatenate_3[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 10)           70          dense_16[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 5)            55          dense_17[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 5)            30          dense_18[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 12)           0           input_1[0][0]
#                                                                  dense_16[0][0]
#                                                                  dense_19[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 6)            78          concatenate_4[0][0]
# __________________________________________________________________________________________________
# dense_21 (Dense)                (None, 5)            35          dense_20[0][0]
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 1)            6           dense_21[0][0]
# ==================================================================================================
# Total params: 1,290
# Trainable params: 1,290
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
keras.utils.plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# ## Fitting the DNN

# %%
device_name = tf.test.gpu_device_name()
if device_name == '/device:GPU:0':
  print('Found GPU at: {}'.format(device_name))
  with tf.device(device_name):
    history = model.fit(x_train,y_train, epochs=30, validation_data=(x_valid,y_valid))
else:
  history = model.fit(x_train,y_train, epochs=500, validation_data=(x_valid,y_valid),callbacks=[lr_scheduler,early_stop])
# Out:
# =============================] - 1s 1ms/step - loss: 0.0097 - val_loss: 0.0104
# Epoch 83/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0108 - val_loss: 0.0155
#
# Epoch 00083: ReduceLROnPlateau reducing learning rate to 0.00011764899536501615.
# Epoch 84/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0086 - val_loss: 0.0074
# Epoch 85/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0075 - val_loss: 0.0082
# Epoch 86/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0080 - val_loss: 0.0064
# Epoch 87/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0076 - val_loss: 0.0064
# Epoch 88/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0071 - val_loss: 0.0089
# Epoch 89/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0080 - val_loss: 0.0083
# Epoch 90/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0080 - val_loss: 0.0067
# Epoch 91/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0074 - val_loss: 0.0084
#
# Epoch 00091: ReduceLROnPlateau reducing learning rate to 0.0001.
# Epoch 92/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0065 - val_loss: 0.0064
# Epoch 93/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0062 - val_loss: 0.0065
# Epoch 94/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0065 - val_loss: 0.0055
# Epoch 95/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0068 - val_loss: 0.0066
# Epoch 96/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0065 - val_loss: 0.0064
# Epoch 97/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0063 - val_loss: 0.0054
# Epoch 98/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0067 - val_loss: 0.0055
# Epoch 99/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0066 - val_loss: 0.0062
# Epoch 100/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0064 - val_loss: 0.0053
# Epoch 101/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0062 - val_loss: 0.0054
# Epoch 102/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0059 - val_loss: 0.0052
# Epoch 103/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0060 - val_loss: 0.0051
# Epoch 104/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0060 - val_loss: 0.0070
# Epoch 105/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0064 - val_loss: 0.0059
# Epoch 106/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0064 - val_loss: 0.0054
# Epoch 107/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0063 - val_loss: 0.0085
# Epoch 108/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0056 - val_loss: 0.0065
# Epoch 109/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0064 - val_loss: 0.0112
# Epoch 110/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0054 - val_loss: 0.0056
# Epoch 111/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0060 - val_loss: 0.0071
# Epoch 112/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0065 - val_loss: 0.0077
# Epoch 113/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0056 - val_loss: 0.0058
# Epoch 114/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0055 - val_loss: 0.0058
# Epoch 115/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0052 - val_loss: 0.0108
# Epoch 116/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0055 - val_loss: 0.0081
# Epoch 117/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0053 - val_loss: 0.0063
# Epoch 118/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0056 - val_loss: 0.0038
# Epoch 119/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0053 - val_loss: 0.0047
# Epoch 120/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0054 - val_loss: 0.0054
# Epoch 121/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0054 - val_loss: 0.0096
# Epoch 122/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0053 - val_loss: 0.0063
# Epoch 123/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0051 - val_loss: 0.0051
# Epoch 124/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0059 - val_loss: 0.0048
# Epoch 125/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0052 - val_loss: 0.0044
# Epoch 126/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0055 - val_loss: 0.0053
# Epoch 127/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0052 - val_loss: 0.0052
# Epoch 128/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0051 - val_loss: 0.0053
# Epoch 129/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0051 - val_loss: 0.0088
# Epoch 130/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0053 - val_loss: 0.0055
# Epoch 131/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0050 - val_loss: 0.0066
# Epoch 132/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0050 - val_loss: 0.0043
# Epoch 133/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0048 - val_loss: 0.0051
# Epoch 134/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0051 - val_loss: 0.0048
# Epoch 135/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0046 - val_loss: 0.0097
# Epoch 136/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0059 - val_loss: 0.0038
# Epoch 137/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0047 - val_loss: 0.0040
# Epoch 138/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0048 - val_loss: 0.0036
# Epoch 139/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0048 - val_loss: 0.0037
# Epoch 140/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0042 - val_loss: 0.0043
# Epoch 141/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0045 - val_loss: 0.0048
# Epoch 142/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0045 - val_loss: 0.0067
# Epoch 143/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0046 - val_loss: 0.0034
# Epoch 144/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0046 - val_loss: 0.0041
# Epoch 145/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0053 - val_loss: 0.0058
# Epoch 146/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0046 - val_loss: 0.0034
# Epoch 147/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0040 - val_loss: 0.0049
# Epoch 148/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0050 - val_loss: 0.0036
# Epoch 149/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0044 - val_loss: 0.0036
# Epoch 150/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0046 - val_loss: 0.0061
# Epoch 151/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0046 - val_loss: 0.0036
# Epoch 152/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 153/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0039 - val_loss: 0.0054
# Epoch 154/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0046 - val_loss: 0.0078
# Epoch 155/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0043 - val_loss: 0.0045
# Epoch 156/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0047 - val_loss: 0.0040
# Epoch 157/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0042 - val_loss: 0.0043
# Epoch 158/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0043 - val_loss: 0.0042
# Epoch 159/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0038 - val_loss: 0.0032
# Epoch 160/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0040 - val_loss: 0.0048
# Epoch 161/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0038 - val_loss: 0.0041
# Epoch 162/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0041 - val_loss: 0.0043
# Epoch 163/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0041 - val_loss: 0.0036
# Epoch 164/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0040 - val_loss: 0.0042
# Epoch 165/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0048 - val_loss: 0.0078
# Epoch 166/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0038 - val_loss: 0.0045
# Epoch 167/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0043 - val_loss: 0.0036
# Epoch 168/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0042 - val_loss: 0.0030
# Epoch 169/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0040 - val_loss: 0.0038
# Epoch 170/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0044 - val_loss: 0.0052
# Epoch 171/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0040 - val_loss: 0.0068
# Epoch 172/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0040 - val_loss: 0.0079
# Epoch 173/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0041 - val_loss: 0.0046
# Epoch 174/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0037 - val_loss: 0.0029
# Epoch 175/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0047 - val_loss: 0.0058
# Epoch 176/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0044 - val_loss: 0.0048
# Epoch 177/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0042 - val_loss: 0.0046
# Epoch 178/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0038 - val_loss: 0.0035
# Epoch 179/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0041 - val_loss: 0.0029
# Epoch 180/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0037 - val_loss: 0.0055
# Epoch 181/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0041 - val_loss: 0.0028
# Epoch 182/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0043 - val_loss: 0.0056
# Epoch 183/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0039 - val_loss: 0.0037
# Epoch 184/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0037 - val_loss: 0.0048
# Epoch 185/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 186/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0038 - val_loss: 0.0029
# Epoch 187/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0038 - val_loss: 0.0044
# Epoch 188/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0037 - val_loss: 0.0036
# Epoch 189/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0036 - val_loss: 0.0030
# Epoch 190/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0039 - val_loss: 0.0042
# Epoch 191/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0038 - val_loss: 0.0029
# Epoch 192/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0037 - val_loss: 0.0028
# Epoch 193/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0039 - val_loss: 0.0050
# Epoch 194/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0037 - val_loss: 0.0024
# Epoch 195/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0037 - val_loss: 0.0039
# Epoch 196/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0037 - val_loss: 0.0028
# Epoch 197/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0034 - val_loss: 0.0037
# Epoch 198/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0039 - val_loss: 0.0031
# Epoch 199/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0040 - val_loss: 0.0028
# Epoch 200/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0036 - val_loss: 0.0032
# Epoch 201/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0037 - val_loss: 0.0031
# Epoch 202/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0033 - val_loss: 0.0036
# Epoch 203/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0041 - val_loss: 0.0039
# Epoch 204/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0037 - val_loss: 0.0049
# Epoch 205/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0035 - val_loss: 0.0036
# Epoch 206/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0035 - val_loss: 0.0023
# Epoch 207/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0039 - val_loss: 0.0026
# Epoch 208/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0043 - val_loss: 0.0028
# Epoch 209/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0040 - val_loss: 0.0026
# Epoch 210/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0035 - val_loss: 0.0067
# Epoch 211/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0035 - val_loss: 0.0042
# Epoch 212/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0036 - val_loss: 0.0034
# Epoch 213/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0042 - val_loss: 0.0033
# Epoch 214/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0033 - val_loss: 0.0030
# Epoch 215/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0035 - val_loss: 0.0026
# Epoch 216/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0038 - val_loss: 0.0030
# Epoch 217/500
# 754/754 [==============================] - 1s 2ms/step - loss: 0.0039 - val_loss: 0.0034
# Epoch 218/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0035 - val_loss: 0.0031
# Epoch 219/500
# 754/754 [==============================] - 1s 2ms/step - loss: 0.0036 - val_loss: 0.0036
# Epoch 220/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0038 - val_loss: 0.0033
# Epoch 221/500
# 754/754 [==============================] - 1s 988us/step - loss: 0.0038 - val_loss: 0.0032
# Epoch 222/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0034 - val_loss: 0.0040
# Epoch 223/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0037 - val_loss: 0.0140
# Epoch 224/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0036 - val_loss: 0.0029
# Epoch 225/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0038 - val_loss: 0.0054
# Epoch 226/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0035 - val_loss: 0.0033
# Epoch 227/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0032 - val_loss: 0.0105
# Epoch 228/500
# 754/754 [==============================] - 1s 2ms/step - loss: 0.0035 - val_loss: 0.0031
# Epoch 229/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0034 - val_loss: 0.0030
# Epoch 230/500
# 754/754 [==============================] - 1s 2ms/step - loss: 0.0037 - val_loss: 0.0036
# Epoch 231/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0035 - val_loss: 0.0034
# Epoch 232/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0041 - val_loss: 0.0028
# Epoch 233/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0032 - val_loss: 0.0042
# Epoch 234/500
# 754/754 [==============================] - 1s 990us/step - loss: 0.0034 - val_loss: 0.0056
# Epoch 235/500
# 754/754 [==============================] - 1s 979us/step - loss: 0.0039 - val_loss: 0.0032
# Epoch 236/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0034 - val_loss: 0.0027
# Epoch 237/500
# 754/754 [==============================] - 1s 980us/step - loss: 0.0034 - val_loss: 0.0029
# Epoch 238/500
# 754/754 [==============================] - 1s 990us/step - loss: 0.0033 - val_loss: 0.0027
# Epoch 239/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0036 - val_loss: 0.0044
# Epoch 240/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0037 - val_loss: 0.0039
# Epoch 241/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0033 - val_loss: 0.0028
# Epoch 242/500
# 754/754 [==============================] - 1s 979us/step - loss: 0.0051 - val_loss: 0.0076
# Epoch 243/500
# 754/754 [==============================] - 1s 968us/step - loss: 0.0032 - val_loss: 0.0027
# Epoch 244/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0031 - val_loss: 0.0025
# Epoch 245/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0032 - val_loss: 0.0034
# Epoch 246/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0035 - val_loss: 0.0042
# Epoch 247/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0035 - val_loss: 0.0027
# Epoch 248/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0036 - val_loss: 0.0027
# Epoch 249/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0036 - val_loss: 0.0039
# Epoch 250/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0033 - val_loss: 0.0034
# Epoch 251/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0039 - val_loss: 0.0031
# Epoch 252/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0039 - val_loss: 0.0032
# Epoch 253/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0035 - val_loss: 0.0041
# Epoch 254/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0027 - val_loss: 0.0035
# Epoch 255/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0034 - val_loss: 0.0060
# Epoch 256/500
# 754/754 [==============================] - 1s 2ms/step - loss: 0.0037 - val_loss: 0.0055
# Epoch 257/500
# 754/754 [==============================] - 1s 2ms/step - loss: 0.0037 - val_loss: 0.0029
# Epoch 258/500
# 754/754 [==============================] - 1s 2ms/step - loss: 0.0033 - val_loss: 0.0065
# Epoch 259/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0036 - val_loss: 0.0022
# Epoch 260/500
# 754/754 [==============================] - 1s 2ms/step - loss: 0.0032 - val_loss: 0.0032
# Epoch 261/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0034 - val_loss: 0.0038
# Epoch 262/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0034 - val_loss: 0.0035
# Epoch 263/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0034 - val_loss: 0.0042
# Epoch 264/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0035 - val_loss: 0.0033
# Epoch 265/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0034 - val_loss: 0.0022
# Epoch 266/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0032 - val_loss: 0.0023
# Epoch 267/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0031 - val_loss: 0.0026
# Epoch 268/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0036 - val_loss: 0.0022
# Epoch 269/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0034 - val_loss: 0.0069
# Epoch 270/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0040 - val_loss: 0.0025
# Epoch 271/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0034 - val_loss: 0.0026
# Epoch 272/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0035 - val_loss: 0.0026
# Epoch 273/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0032 - val_loss: 0.0025
# Epoch 274/500
# 754/754 [==============================] - 1s 1ms/step - loss: 0.0032 - val_loss: 0.0039

# %%
mse_test = model.evaluate(x_test, y_test)
# Out:
# 236/236 [==============================] - 0s 536us/step - loss: 0.0032

# %%
x_new = np.arange(-4*np.pi,4*np.pi+step*100,step*100)
y_new = model.predict(x_new)
plt.plot(x_new,y_new,',b')
plt.plot(x,y,'r')
